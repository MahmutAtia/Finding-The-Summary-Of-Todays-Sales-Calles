# %% [markdown]
# ## Importing Libraries And Load The Data

# %%
from google.colab import files
files.upload()

# %%
! pip install googletrans==4.0.0-rc1
from googletrans import Translator
#translator = Translator(service_urls=['translate.googleapis.com'])
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
pathlist = ["/content/(AL) SIRMA METAL  - İhracat Sistemi - Made by Muhammet AKMAN (4).xlsx",
 "/content/(MA) SIRMA METAL  - İhracat Sistemi - Made by Muhammet AKMAN (2).xlsx",
 "/content/(MOUSTAPHA) SIRMA METAL  - İhracat Sistemi - Made by Muhammet AKMAN (1).xlsx"]
df_list = []
quote_list = []
for df in pathlist:
   f = pd.ExcelFile(df)
   df_list.append( pd.read_excel(f,"ARAMA LİSTELERİ"))
   try:
    quote_list.append( pd.read_excel(f,"VERİLEN TEKLİFLER1"))
   except:
    quote_list.append( pd.read_excel(f,"VERİLEN TEKLİFLER"))

# %% [markdown]
# ## Solving an annoying problem probelm

# %% [markdown]
# I joined the 3 data frame in one table and did a country analysis, but I find later that the 3 data frame have some deffrent columns names so that I yeild bad results

# %%
df_list[2].iloc[:,6:].head()
# Out:
#             Unnamed: 6       Unnamed: 7                     Unnamed: 8  \
# 0     TELEFON NUMARASI   FİRMA YETKLİSİ                     WEB SİTESİ
# 1     000 270861365970              NaN           quote@ezrailsdiy.com
# 2       224664214545.0              NaN            https://saccof.com/
# 3       224664535886.0              NaN  https://www.ejico-guinee.com/
# 4  \n+224 664 31 49 17  diabate ousmane          www.gescheafrique.com
#
#                                    Unnamed: 9     Unnamed: 10  \
# 0                              SOSYAL MEDYA 1  SOSYAL MEDYA 2
# 1                                         NaN             NaN
# 2                                         NaN             NaN
# 3                                         NaN             NaN
# 4  https://www.facebook.com/gescheafriquesarl             NaN
#
#    FİRMA İLİŞKİLERİ          Unnamed: 12         Unnamed: 13  \
# 0  1. İRTİBAT ŞEKLİ   1. İRTİBAT TARİHİ    1. İRTİBAT SONUCU
# ...

# %%
len(df_list[0].columns) , len(df_list[1].columns) ,len(df_list[2].columns)
# Out:
# (24, 24, 25)

# %%
df_list[0].columns
# Out:
# Index(['FİRMA GENEL BİLGİLERİ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'FİRMA İLİŞKİLERİ', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')

# %%
df_list[1].columns
# Out:
# Index(['FİRMA GENEL BİLGİLERİ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')

# %%
df_list[2].columns
# Out:
# Index(['FİRMA GENEL BİLGİLERİ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'FİRMA İLİŞKİLERİ', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %% [markdown]
# solving the problem by droping 24. column in the third data frame and renaming all the columns

# %%
for i in df_list:
  try:
    i.drop('Unnamed: 24', axis=1, inplace = True)
    i.columns = ['NO', 'EKLEYEN', 'FİRMA ADI', 'ÜLKE', 'FAALİYET', 'E-POSTA',
       'TELEFON NUMARASI', 'FİRMA YETKLİSİ', 'WEB SİTESİ', 'SOSYAL MEDYA 1',
       'SOSYAL MEDYA 2', '1. İRTİBAT ŞEKLİ', '1. İRTİBAT TARİHİ',
       '1. İRTİBAT SONUCU', '2. İRTİBAT ŞEKLİ', '2. İRTİBAT TARİHİ',
       '2. İRTİBAT SONUCU', '3. İRTİBAT ŞEKLİ', '3. İRTİBAT TARİHİ',
       '3. İRTİBAT SONUCU', '4. İRTİBAT ŞEKLİ', '4. İRTİBAT TARİHİ',
       '4. İRTİBAT SONUCU', 'NOTLAR']
  except:
    i.columns = ['NO', 'EKLEYEN', 'FİRMA ADI', 'ÜLKE', 'FAALİYET', 'E-POSTA',
       'TELEFON NUMARASI', 'FİRMA YETKLİSİ', 'WEB SİTESİ', 'SOSYAL MEDYA 1',
       'SOSYAL MEDYA 2', '1. İRTİBAT ŞEKLİ', '1. İRTİBAT TARİHİ',
       '1. İRTİBAT SONUCU', '2. İRTİBAT ŞEKLİ', '2. İRTİBAT TARİHİ',
       '2. İRTİBAT SONUCU', '3. İRTİBAT ŞEKLİ', '3. İRTİBAT TARİHİ',
       '3. İRTİBAT SONUCU', '4. İRTİBAT ŞEKLİ', '4. İRTİBAT TARİHİ',
       '4. İRTİBAT SONUCU', 'NOTLAR']

# %%
df_list[1].columns
# Out:
# Index(['NO', 'EKLEYEN', 'FİRMA ADI', 'ÜLKE', 'FAALİYET', 'E-POSTA',
#        'TELEFON NUMARASI', 'FİRMA YETKLİSİ', 'WEB SİTESİ', 'SOSYAL MEDYA 1',
#        'SOSYAL MEDYA 2', '1. İRTİBAT ŞEKLİ', '1. İRTİBAT TARİHİ',
#        '1. İRTİBAT SONUCU', '2. İRTİBAT ŞEKLİ', '2. İRTİBAT TARİHİ',
#        '2. İRTİBAT SONUCU', '3. İRTİBAT ŞEKLİ', '3. İRTİBAT TARİHİ',
#        '3. İRTİBAT SONUCU', '4. İRTİBAT ŞEKLİ', '4. İRTİBAT TARİHİ',
#        '4. İRTİBAT SONUCU', 'NOTLAR'],
#       dtype='object')

# %%
(df_list[1]['1. İRTİBAT ŞEKLİ'][df_list[1]['ÜLKE']=="Umman"]).count()
# Out:
# 71

# %% [markdown]
# I think problem solved

# %% [markdown]
# ## Preprocessing The Data

# %% [markdown]
# ### Make Them One Data Frame

# %%
calls_list_all = pd.concat(df_list)

# %%
calls_list_all.describe()
# Out:
#           NO EKLEYEN  FİRMA ADI  ÜLKE         FAALİYET E-POSTA  \
# count   2503    2506       2597  2543             1978     306
# unique  1007       4       2528    79               26     250
# top       NO      MA  FİRMA ADI  Irak  Kapı ve Pencere    مكرر
# freq       3    1009          3   707             1069      26
#
#         TELEFON NUMARASI FİRMA YETKLİSİ  WEB SİTESİ SOSYAL MEDYA 1  ...  \
# count               2496            553         592            461  ...
# unique              2417            439         586            451  ...
# top     TELEFON NUMARASI            ALİ  WEB SİTESİ             \n  ...
# freq                   3             23           3              4  ...
#
#        2. İRTİBAT ŞEKLİ    2. İRTİBAT TARİHİ   2. İRTİBAT SONUCU  \
# count              1056                 1065                1007
# unique                6                   58                  43
# top               ARAMA  2022-12-06 00:00:00  KATALOG GÖNDERİLDİ
# ...

# %%
calls_list_all.iloc[:,11:].describe()
# Out:
#        1. İRTİBAT ŞEKLİ    1. İRTİBAT TARİHİ   1. İRTİBAT SONUCU  \
# count              2328                 2268                1715
# unique                7                   78                  40
# top               ARAMA  2022-11-28 00:00:00  KATALOG GÖNDERİLDİ
# freq               1712                  170                 779
#
#        2. İRTİBAT ŞEKLİ    2. İRTİBAT TARİHİ   2. İRTİBAT SONUCU  \
# count              1056                 1065                1007
# unique                6                   58                  43
# top               ARAMA  2022-12-06 00:00:00  KATALOG GÖNDERİLDİ
# freq                602                   87                 297
#
#        3. İRTİBAT ŞEKLİ    3. İRTİBAT TARİHİ 3. İRTİBAT SONUCU  \
# count               424                  423               418
# unique                5                   39                27
# top            WHATSAPP  2022-11-28 00:00:00    DEĞELENDİRECEK
# ...

# %% [markdown]
# Check for NA values in Company columns

# %%
columns =calls_list_all.columns

# %%
columns
# Out:
# Index(['NO', 'EKLEYEN', 'FİRMA ADI', 'ÜLKE', 'FAALİYET', 'E-POSTA',
#        'TELEFON NUMARASI', 'FİRMA YETKLİSİ', 'WEB SİTESİ', 'SOSYAL MEDYA 1',
#        'SOSYAL MEDYA 2', '1. İRTİBAT ŞEKLİ', '1. İRTİBAT TARİHİ',
#        '1. İRTİBAT SONUCU', '2. İRTİBAT ŞEKLİ', '2. İRTİBAT TARİHİ',
#        '2. İRTİBAT SONUCU', '3. İRTİBAT ŞEKLİ', '3. İRTİBAT TARİHİ',
#        '3. İRTİBAT SONUCU', '4. İRTİBAT ŞEKLİ', '4. İRTİBAT TARİHİ',
#        '4. İRTİBAT SONUCU', 'NOTLAR'],
#       dtype='object')

# %%
print(f"we have {(calls_list_all['FİRMA ADI'].isna()).sum()} NA values")
# Out:
# we have 940 NA values

# %%
cleaned_calls_list = calls_list_all[calls_list_all['FİRMA ADI'].isna()==False]

# %%
cleaned_calls_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2597 entries, 0 to 589
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NO                 2503 non-null   object
#  1   EKLEYEN            2506 non-null   object
#  2   FİRMA ADI          2597 non-null   object
#  3   ÜLKE               2543 non-null   object
#  4   FAALİYET           1978 non-null   object
#  5   E-POSTA            306 non-null    object
#  6   TELEFON NUMARASI   2496 non-null   object
#  7   FİRMA YETKLİSİ     553 non-null    object
#  8   WEB SİTESİ         592 non-null    object
#  9   SOSYAL MEDYA 1     461 non-null    object
#  10  SOSYAL MEDYA 2     13 non-null     object
#  11  1. İRTİBAT ŞEKLİ   2328 non-null   object
#  12  1. İRTİBAT TARİHİ  2268 non-null   object
#  13  1. İRTİBAT SONUCU  1715 non-null   object
#  14  2. İRTİBAT ŞEKLİ   1056 non-null   object
#  15  2. İRTİBAT TARİHİ  1065 non-null   object
# ...

# %% [markdown]
# Solve NAs problem in person columns

# %%
cleaned_calls_list["EKLEYEN"].value_counts(), print(f"\nThere are {(cleaned_calls_list['EKLEYEN'].isna()).sum()} NAs\n\n")
# Out:
# There are 91 NAs
# (MA         1009
#  AL          905
#  FAD         589
#  EKLEYEN       3
#  Name: EKLEYEN, dtype: int64, None)

# %%
# I have problems in my sheet so there ara NAs intead of MA
cleaned_calls_list["EKLEYEN"] = cleaned_calls_list["EKLEYEN"].fillna("MA")
# Out:
# <ipython-input-28-430dbb366183>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_calls_list["EKLEYEN"] = cleaned_calls_list["EKLEYEN"].fillna("MA")

# %%
cleaned_calls_list["EKLEYEN"].value_counts(), print(f"\nThere are {(cleaned_calls_list['EKLEYEN'].isna()).sum()} NAs\n\n")
# Out:
# There are 0 NAs
# (MA         1100
#  AL          905
#  FAD         589
#  EKLEYEN       3
#  Name: EKLEYEN, dtype: int64, None)

# %%
cleaned_calls_list[cleaned_calls_list["EKLEYEN"]=="EKLEYEN"]
# Out:
#    NO  EKLEYEN  FİRMA ADI  ÜLKE  FAALİYET  E-POSTA  TELEFON NUMARASI  \
# 0  NO  EKLEYEN  FİRMA ADI  ÜLKE  FAALİYET  E-POSTA  TELEFON NUMARASI
# 0  NO  EKLEYEN  FİRMA ADI  ÜLKE  FAALİYET  E-POSTA  TELEFON NUMARASI
# 0  NO  EKLEYEN  FİRMA ADI  ÜLKE  FAALİYET  E-POSTA  TELEFON NUMARASI
#
#    FİRMA YETKLİSİ  WEB SİTESİ  SOSYAL MEDYA 1  ...  2. İRTİBAT ŞEKLİ  \
# 0  FİRMA YETKLİSİ  WEB SİTESİ  SOSYAL MEDYA 1  ...  2. İRTİBAT ŞEKLİ
# 0  FİRMA YETKLİSİ  WEB SİTESİ  SOSYAL MEDYA 1  ...  2. İRTİBAT ŞEKLİ
# 0  FİRMA YETKLİSİ  WEB SİTESİ  SOSYAL MEDYA 1  ...  2. İRTİBAT ŞEKLİ
#
#     2. İRTİBAT TARİHİ  2. İRTİBAT SONUCU  3. İRTİBAT ŞEKLİ  \
# 0  2. İRTİBAT TARİHİ   2. İRTİBAT SONUCU  3. İRTİBAT ŞEKLİ
# 0  2. İRTİBAT TARİHİ   2. İRTİBAT SONUCU  3. İRTİBAT ŞEKLİ
# 0  2. İRTİBAT TARİHİ   2. İRTİBAT SONUCU  3. İRTİBAT ŞEKLİ
#
#     3. İRTİBAT TARİHİ  3. İRTİBAT SONUCU  4. İRTİBAT ŞEKLİ  \
# 0  3. İRTİBAT TARİHİ   3. İRTİBAT SONUCU  4. İRTİBAT ŞEKLİ
# ...

# %% [markdown]
# we have to get rid of these also

# %%
drop_index = cleaned_calls_list[cleaned_calls_list["EKLEYEN"]=="EKLEYEN"].index

# %%
cleaned_calls_list.drop(drop_index, axis = 0, inplace=True)

# %%
cleaned_calls_list["EKLEYEN"].value_counts(), print(f"\nThere are {(cleaned_calls_list['EKLEYEN'].isna()).sum()} NAs\n\n")
# Out:
# There are 0 NAs
# (MA     1100
#  AL      905
#  FAD     589
#  Name: EKLEYEN, dtype: int64, None)

# %%
cleaned_calls_list.iloc[:,1:].to_excel("df.xlsx")

# %% [markdown]
# Well Done!

# %% [markdown]
# ## Company Analysis

# %%
print(pd.DataFrame({
"Aranan Şirket Sayısı" : [len(cleaned_calls_list['FİRMA ADI'])],
"Aranan Şirket Sayısı Tekrarsız" : [len(cleaned_calls_list['FİRMA ADI'].unique())],
"Aranan Ülkeler Sayısı" : [len(cleaned_calls_list['ÜLKE'].dropna().unique())]
}
))
# Out:
#    Aranan Şirket Sayısı  Aranan Şirket Sayısı Tekrarsız  Aranan Ülkeler Sayısı
# 0                  2594                            2527                     78

# %% [markdown]
# ## Couuntry Analysis

# %% [markdown]
# Group by country

# %%
df_country = cleaned_calls_list.groupby("ÜLKE").count().sort_values(by=["FİRMA ADI"], axis = 0, ascending=False )

# %% [markdown]
# Creating subset for country analysis

# %%
df_country.columns
# Out:
# Index(['NO', 'EKLEYEN', 'FİRMA ADI', 'FAALİYET', 'E-POSTA', 'TELEFON NUMARASI',
#        'FİRMA YETKLİSİ', 'WEB SİTESİ', 'SOSYAL MEDYA 1', 'SOSYAL MEDYA 2',
#        '1. İRTİBAT ŞEKLİ', '1. İRTİBAT TARİHİ', '1. İRTİBAT SONUCU',
#        '2. İRTİBAT ŞEKLİ', '2. İRTİBAT TARİHİ', '2. İRTİBAT SONUCU',
#        '3. İRTİBAT ŞEKLİ', '3. İRTİBAT TARİHİ', '3. İRTİBAT SONUCU',
#        '4. İRTİBAT ŞEKLİ', '4. İRTİBAT TARİHİ', '4. İRTİBAT SONUCU', 'NOTLAR'],
#       dtype='object')

# %%
df_country[['FİRMA ADI','1. İRTİBAT ŞEKLİ','2. İRTİBAT ŞEKLİ','3. İRTİBAT ŞEKLİ','4. İRTİBAT ŞEKLİ']].iloc[:15]
# Out:
#                            FİRMA ADI  1. İRTİBAT ŞEKLİ  2. İRTİBAT ŞEKLİ  \
# ÜLKE
# Irak                             707               700               531
# Almanya                          268               259                37
# Lübnan                           142               135                70
# FAS                              119               115                 1
# Fransa                            89                85                41
# Suudi Arabistan                   83                78                 9
# Benin                             83                51                20
# Cezayir                           77                74                 1
# Umman                             75                71                53
# Katar                             74                68                27
# Kuveyt                            71                69                55
# Libya                             64                 7                 3
# ...

# %% [markdown]
# ## Contact Methods Analysis

# %%
cleaned_calls_list.columns
# Out:
# Index(['NO', 'EKLEYEN', 'FİRMA ADI', 'ÜLKE', 'FAALİYET', 'E-POSTA',
#        'TELEFON NUMARASI', 'FİRMA YETKLİSİ', 'WEB SİTESİ', 'SOSYAL MEDYA 1',
#        'SOSYAL MEDYA 2', '1. İRTİBAT ŞEKLİ', '1. İRTİBAT TARİHİ',
#        '1. İRTİBAT SONUCU', '2. İRTİBAT ŞEKLİ', '2. İRTİBAT TARİHİ',
#        '2. İRTİBAT SONUCU', '3. İRTİBAT ŞEKLİ', '3. İRTİBAT TARİHİ',
#        '3. İRTİBAT SONUCU', '4. İRTİBAT ŞEKLİ', '4. İRTİBAT TARİHİ',
#        '4. İRTİBAT SONUCU', 'NOTLAR'],
#       dtype='object')

# %%
contact_methods = []
for i in range(1,5):
  methods = f"{i}. İRTİBAT ŞEKLİ"
  subset = cleaned_calls_list[['EKLEYEN', 'FİRMA ADI', 'ÜLKE', methods]].rename( {methods:"contact_method"},axis=1)
  contact_methods.append(subset)
contact_methods_df = pd.concat(contact_methods, axis=0)

# %% [markdown]
# missing values in first call

# %%
df = contact_methods[0]

# %%
for i in ["MA","AL","FAD"]:
  NAs = (df["contact_method"][df['EKLEYEN']==i]).isna().sum()
  print(f" {i} have {NAs} missing values in first contact")
# Out:
#  MA have 113 missing values in first contact
#  AL have 11 missing values in first contact
#  FAD have 145 missing values in first contact

# %%
contact2company = contact_methods_df.drop(['EKLEYEN','ÜLKE'], axis=1).groupby("contact_method").count().iloc[1:].sort_values(by=["FİRMA ADI"], axis = 0, ascending=False )

# %%
contact2company
# Out:
#                      FİRMA ADI
# contact_method
# ARAMA                     2528
# WHATSAPP                  1043
# E-POSTA                    375
# SOSYAL MEDYA                23
# 2022-12-14 00:00:00          1
# TELEGRAM                     1

# %%
contact_methods_df['EKLEYEN'] = contact_methods_df['EKLEYEN'].map({"MA" : "Mahmoud","AL":"Ali","FAD":"Fadil and Moustafa"})
contact2person = contact_methods_df.drop(['ÜLKE'], axis=1).groupby(['EKLEYEN',"contact_method"]).count().sort_values(by=["EKLEYEN", "contact_method"], axis = 0, ascending=False )

# %%
df_without_na = contact_methods_df[contact_methods_df["contact_method"].isna()==False]

# %%
df_without_na
# Out:
#       EKLEYEN                                 FİRMA ADI    ÜLKE contact_method
# 1         Ali          Al Wessam Alüminyum İşleri p.v.c    Irak          ARAMA
# 2         Ali                        küçük ev fabrikası    Irak          ARAMA
# 3         Ali                       Al Rasoul Fabrikası    Irak          ARAMA
# 4         Ali     Barakat Al Zahraa Alüminyum Fabrikası    Irak          ARAMA
# 5         Ali  Genel Ticaret ve Alüminyum Dijla Şirketi    Irak          ARAMA
# ...       ...                                       ...     ...            ...
# 779   Mahmoud                          Aluminum Watad\n   Umman       WHATSAPP
# 781   Mahmoud          Modern Aluminium Services LLc.\n   Umman          ARAMA
# 804   Mahmoud                             Folda Qatar\n   Katar          ARAMA
# 923   Mahmoud                    Al Mimari Industries\n   Umman       WHATSAPP
# 2022  Mahmoud  Daldhis Aluminium & Decoration Factory\n  Somali          ARAMA
#
# [3972 rows x 4 columns]

# %% [markdown]
# adding country names in english

# %%
with open("ülke.txt" , "w") as f:
  f.write(str(list(df_without_na["ÜLKE"])))

# %%
trans.translate("seviyorum").text

# %%
ülke = [google_translate(x, "tr") for x in list(df_without_na["ÜLKE"])]

# %%
df_without_na['ülke_en'] = ülke
# Out:
# <ipython-input-82-661a783bd1b4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_without_na['ülke_en'] = ülke

# %%
df_without_na.describe()
# Out:
#        EKLEYEN                         FİRMA ADI  ÜLKE contact_method ülke_en
# count     3972                              3972  3953           3972    3972
# unique       3                              2302    74              7      72
# top        Ali  Modern Aluminium Services LLc.\n  Irak          ARAMA    Iraq
# freq      1802                                 6  1598           2528    1599

# %%
df_without_na.ülke_en.unique(),df_without_na.ÜLKE.unique()
# Out:
# (array(['Iraq', 'Libya', 'Saudi Arabia', 'Kuwait', 'Jordan', 'Nan',
#         'Algeria', 'MOROCCO', 'Mauritanie', 'United Arab Emirates',
#         'South Africa', 'Lebanon', 'Philippines', 'Germany', 'Namibia',
#         'Train', 'Morocco', 'United Kingdom', 'USA', 'Oman', 'Malaysia',
#         'Azerbaijan', 'Georgian', 'Armenia', 'Tajikistan', 'Turkmenistan',
#         'Uzbekistan', 'Tanzania', 'Kenya', 'Nigeria', 'Yemen', 'Tunisia',
#         'France', 'Kazakhistan', 'Iranian', 'Chile', 'South Sudan',
#         'Sweetcorn', 'Bulgaria', 'Serbia', 'Palestine', 'Sweden', 'Malta',
#         'Mauritania', 'Macedonia', 'Senegal', 'Bahrain', 'Chinese',
#         'Cyprus Republic', 'Finland', 'India', 'Poland', 'Somali',
#         'Romania', 'Liberia', 'Austria', 'Pakistan', 'Switzerland',
#         'Denmark', 'Syria', 'Guinea', 'Ivory Coast',
#         'Democratic Republic of Congo', 'Chad', 'Republic of Congo',
#         'Rwanda', 'Sudan', 'Ghana', 'Ethiopia', 'Belgium', 'Luxembourg',
# ...

# %%
df_without_na.to_excel("contact.xlsx")

# %%
contact2person
# Out:
#                                         FİRMA ADI
# EKLEYEN            contact_method
# Mahmoud            WHATSAPP                   122
#                    SOSYAL MEDYA                 8
#                    E-POSTA                    253
#                    ARAMA                     1180
#                    2022-10-24 00:00:00          1
# Fadil and Moustafa WHATSAPP                   124
#                    TELEGRAM                     1
#                    E-POSTA                    111
#                    ARAMA                      370
# Ali                WHATSAPP                   797
#                    SOSYAL MEDYA                15
#                    E-POSTA                     11
#                    ARAMA                      978
#                    2022-12-14 00:00:00          1

# %%
contact2person = contact2person.drop(contact2person.index[4])

# %%
contact2person
# Out:
#                                         FİRMA ADI
# EKLEYEN            contact_method
# Mahmoud            WHATSAPP                   122
#                    SOSYAL MEDYA                 8
#                    E-POSTA                    253
#                    ARAMA                     1180
# Fadil and Moustafa WHATSAPP                   124
#                    TELEGRAM                     1
#                    E-POSTA                    111
#                    ARAMA                      370
# Ali                WHATSAPP                   797
#                    SOSYAL MEDYA                15
#                    E-POSTA                     11
#                    ARAMA                      978
#                    2022-12-14 00:00:00          1

# %%
# contact type analysis
contact = []
for i in range(1,5):
 contact.append( pd.DataFrame(calls_list_all[f"{i}. İRTİBAT ŞEKLİ"].dropna().value_counts()))

contact2contact = pd.concat(contact, axis=1).iloc[:-4].drop(["1. İRTİBAT ŞEKLİ"],axis=0)
contact2contact
# Out:
#                      1. İRTİBAT ŞEKLİ  2. İRTİBAT ŞEKLİ  3. İRTİBAT ŞEKLİ  \
# ARAMA                          1712.0             602.0             143.0
# E-POSTA                         312.0              30.0              31.0
# WHATSAPP                        286.0             413.0             244.0
# SOSYAL MEDYA                     13.0               7.0               3.0
# 2022-12-14 00:00:00               1.0               NaN               NaN
# TELEGRAM                          1.0               NaN               NaN
#
#                      4. İRTİBAT ŞEKLİ
# ARAMA                            71.0
# E-POSTA                           2.0
# WHATSAPP                        100.0
# SOSYAL MEDYA                      NaN
# 2022-12-14 00:00:00               NaN
# TELEGRAM                          NaN

# %%
 contact2country = contact_methods_df.drop(["EKLEYEN"], axis=1).groupby(['ÜLKE',"contact_method"]).count().sort_values(by=["FİRMA ADI"], axis = 0, ascending=False )

# %%
contact2country
# Out:
#                                    FİRMA ADI
# ÜLKE               contact_method
# Irak               ARAMA                 798
#                    WHATSAPP              785
# Lübnan             ARAMA                 189
# Almanya            ARAMA                 166
#                    E-POSTA               154
# ...                                      ...
# Kıbrıs Cumhuriyeti WHATSAPP                1
# Libya              SOSYAL MEDYA            1
# Mısır              SOSYAL MEDYA            1
# Nijerya            SOSYAL MEDYA            1
# Şili               ARAMA                   1
#
# [141 rows x 1 columns]

# %% [markdown]
# ## working  with call results
