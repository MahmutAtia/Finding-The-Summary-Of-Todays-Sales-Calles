# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b1ed80e4-1faa-4107-8453-4a4709b9bafc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1ed80e4-1faa-4107-8453-4a4709b9bafc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
pathlist = ["/content/(AL) SIRMA METAL  - İhracat Sistemi - Made by Muhammet AKMAN.xlsx",
 "/content/(MA) SIRMA METAL  - İhracat Sistemi - Made by Muhammet AKMAN.xlsx",
 "/content/(MOUSTAPHA) SIRMA METAL  - İhracat Sistemi - Made by Muhammet AKMAN.xlsx"]
df_list = []
quote_list = []
for df in pathlist:
   f = pd.ExcelFile(df)
   df_list.append( pd.read_excel(f,"ARAMA LİSTELERİ"))
   try:
    quote_list.append( pd.read_excel(f,"VERİLEN TEKLİFLER1"))
   except:
    quote_list.append( pd.read_excel(f,"VERİLEN TEKLİFLER"))

# %%
calls_list_all = pd.concat(df_list)

# %%
calls_list_all.columns = calls_list_all.iloc[0]

# %%
calls_list_all.describe()
# Out:
# 0         NO EKLEYEN  FİRMA ADI  ÜLKE         FAALİYET E-POSTA  \
# count   2503    2506       2596  2541             1977     302
# unique  1007       4       2527    79               26     249
# top       NO      MA  FİRMA ADI  Irak  Kapı ve Pencere    مكرر
# freq       3    1009          3   707             1069      23
#
# 0       TELEFON NUMARASI FİRMA YETKLİSİ  WEB SİTESİ SOSYAL MEDYA 1  ...  \
# count               2494            514         590            461  ...
# unique              2414            411         584            451  ...
# top     TELEFON NUMARASI            ALİ  WEB SİTESİ             \n  ...
# freq                   3             23           3              4  ...
#
# 0        2. İRTİBAT SONUCU 3. İRTİBAT ŞEKLİ   3. İRTİBAT TARİHİ   \
# count                  972              400                  399
# unique                  42                5                   37
# top     KATALOG GÖNDERİLDİ         WHATSAPP  2022-11-28 00:00:00
# ...

# %%
calls_list_all.iloc[:,11:].describe()
# Out:
# 0      1. İRTİBAT ŞEKLİ   1. İRTİBAT TARİHİ    1. İRTİBAT SONUCU  \
# count              1239                 2168                1614
# unique                6                   75                  39
# top               ARAMA  2022-11-28 00:00:00  KATALOG GÖNDERİLDİ
# freq                877                  170                 723
#
# 0      2. İRTİBAT ŞEKLİ   2. İRTİBAT TARİHİ    2. İRTİBAT SONUCU  \
# count              1020                 1029                 972
# unique                6                   55                  42
# top               ARAMA  2022-12-06 00:00:00  KATALOG GÖNDERİLDİ
# freq                581                   87                 294
#
# 0      3. İRTİBAT ŞEKLİ   3. İRTİBAT TARİHİ  3. İRTİBAT SONUCU  \
# count               400                  399               395
# unique                5                   37                26
# top            WHATSAPP  2022-11-28 00:00:00    DEĞELENDİRECEK
# ...

# %%
pd.DataFrame({
"Aranan Şirket Sayısı" : [len(calls_list_all['FİRMA ADI'].dropna())],
"Aranan Şirket Sayısı Tekrarsız" : [len(calls_list_all['FİRMA ADI'].unique())],
"Aranan Ülkeler Sayısı" : [len(calls_list_all['ÜLKE'].dropna().unique())]
}
)
# Out:
#    Aranan Şirket Sayısı  Aranan Şirket Sayısı Tekrarsız  Aranan Ülkeler Sayısı
# 0                  2596                            2528                     79

# %%
# country analysis
countrıes = pd.DataFrame(calls_list_all['ÜLKE'].dropna().value_counts())

# %%
countrıes.to_excel('country.xlsx')

# %%
# contact type analysis
contact = []
for i in range(1,5):
 contact.append( pd.DataFrame(calls_list_all[f"{i}. İRTİBAT ŞEKLİ"].dropna().value_counts()))

contact_df = pd.concat(contact, axis=1).iloc[:-4].drop(["1. İRTİBAT ŞEKLİ"],axis=0)
contact_df
# Out:
#               1. İRTİBAT ŞEKLİ  2. İRTİBAT ŞEKLİ  3. İRTİBAT ŞEKLİ  \
# ARAMA                    789.0             576.0             138.0
# WHATSAPP                 251.0             398.0             222.0
# E-POSTA                  102.0              30.0              31.0
# SOSYAL MEDYA               4.0               7.0               3.0
# TELEGRAM                   1.0               NaN               NaN
#
#               4. İRTİBAT ŞEKLİ
# ARAMA                     64.0
# WHATSAPP                  94.0
# E-POSTA                    2.0
# SOSYAL MEDYA               NaN
# TELEGRAM                   NaN

# %%
pd.DataFrame(contact_df.sum(axis=1), columns= ["Toplam"])
# Out:
#               Toplam
# ARAMA         1567.0
# WHATSAPP       965.0
# E-POSTA        165.0
# SOSYAL MEDYA    14.0
# TELEGRAM         1.0
